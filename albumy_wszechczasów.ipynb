# %% [markdown]
# Import bibliotek i danych

# %%
import pandas as pd


df = pd.read_csv('danee.csv')
print(df)
# Out:
#     Unnamed: 0  POS                                   TITLE  \
# 0          NaN    1                           GREATEST HITS
# 1          NaN    2                    GOLD - GREATEST HITS
# 2          NaN    3    SGT PEPPER'S LONELY HEARTS CLUB BAND
# 3          NaN    4                                      21
# 4          NaN    5          WHAT'S THE STORY MORNING GLORY
# 5          NaN    6                                THRILLER
# 6          NaN    7               THE DARK SIDE OF THE MOON
# 7          NaN    8                        BROTHERS IN ARMS
# 8          NaN    9                                     BAD
# 9          NaN   10                        GREATEST HITS II
# 10         NaN   11                                 RUMOURS
# 11         NaN   12               THE IMMACULATE COLLECTION
# 12         NaN   13                           BACK TO BLACK
# 13         NaN   14                                   STARS
# 14         NaN   15                            COME ON OVER
# ...

# %% [markdown]
# 1. Zamień nagłówki kolumn na polskie odpowiedniki:

# %%
df = df.rename(columns={'POS':'POZYCJA','TITLE':'TYTUŁ','ARTIST':'ARTYSTA','YEAR':'ROK','HIGH POSN':'MAX POZ'})
df = df[['POZYCJA','TYTUŁ','ARTYSTA','ROK','MAX POZ']]
print(df)
# Out:
#     POZYCJA                                   TYTUŁ                   ARTYSTA  \
# 0         1                           GREATEST HITS                     QUEEN
# 1         2                    GOLD - GREATEST HITS                      ABBA
# 2         3    SGT PEPPER'S LONELY HEARTS CLUB BAND                   BEATLES
# 3         4                                      21                     ADELE
# 4         5          WHAT'S THE STORY MORNING GLORY                     OASIS
# 5         6                                THRILLER           MICHAEL JACKSON
# 6         7               THE DARK SIDE OF THE MOON                PINK FLOYD
# 7         8                        BROTHERS IN ARMS              DIRE STRAITS
# 8         9                                     BAD           MICHAEL JACKSON
# 9        10                        GREATEST HITS II                     QUEEN
# 10       11                                 RUMOURS             FLEETWOOD MAC
# ...

# %% [markdown]
# 2. Ilu pojedynczych artystów znajduje się na liście?

# %%
df['ARTYSTA'].nunique()
# Out:
# 47

# %% [markdown]
# 3.Które zespoły pojawiają się najczęściej na liście?

# %%
counts = df['ARTYSTA'].value_counts()

max_labels = counts[counts == max_count].index

print(max_labels )
# Out:
# Index(['COLDPLAY', 'TAKE THAT'], dtype='object')

# %% [markdown]
# 4. Zmień nagłówki kolumn, tak aby każdy z nich rozpoczynał się od wielkiej litery, a pozostałe były wprowadzone małymi literami.

# %%
df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
df.columns = df.columns.str.title()
print(df)
# Out:
#     Pozycja                                   Tytuł                   Artysta  \
# 0         1                           greatest hits                     queen
# 1         2                    gold - greatest hits                      abba
# 2         3    sgt pepper's lonely hearts club band                   beatles
# 3         4                                      21                     adele
# 4         5          what's the story morning glory                     oasis
# 5         6                                thriller           michael jackson
# 6         7               the dark side of the moon                pink floyd
# 7         8                        brothers in arms              dire straits
# 8         9                                     bad           michael jackson
# 9        10                        greatest hits ii                     queen
# 10       11                                 rumours             fleetwood mac
# ...

# %% [markdown]
# 5.Wyrzuć z tabeli kolumnę ‘Max Poz’.

# %%
df = df.drop(columns=['Max Poz'])
print(df)
# Out:
#     Pozycja                                   Tytuł                   Artysta  \
# 0         1                           greatest hits                     queen
# 1         2                    gold - greatest hits                      abba
# 2         3    sgt pepper's lonely hearts club band                   beatles
# 3         4                                      21                     adele
# 4         5          what's the story morning glory                     oasis
# 5         6                                thriller           michael jackson
# 6         7               the dark side of the moon                pink floyd
# 7         8                        brothers in arms              dire straits
# 8         9                                     bad           michael jackson
# 9        10                        greatest hits ii                     queen
# 10       11                                 rumours             fleetwood mac
# ...

# %% [markdown]
# 6.W którym roku wyszło najwięcej albumów znajdujących się na liście?

# %%
count1 = df['Rok'].value_counts()
max_count1 = count1.max()
max_labels1 = count1[liczone1 == max_count1].index
print(max_labels1)
# Out:
# Int64Index([2000, 1987], dtype='int64')

# %%
7.Ile albumów wydanych między 1960 a 1990 rokiem włącznie znajduje się na liście?

# %%
cond = (df['Rok'] >= 1960) & (df['Rok'] <= 1990)
albums_count = len(df[cond])
print(albums_count)
# Out:
# 22

# %% [markdown]
# 8.W którym roku wydany został najmłodszy album na liście?

# %%
df.loc[df['Rok'] == df['Rok'].min()]
# Out:
#     Pozycja               Tytuł                  Artysta   Rok
# 51       52  the sound of music  original cast recording  1965

# %%
earliest_albums = df.groupby('Artysta').apply(lambda x: x.loc[x['Rok'].idxmin()])
earliest_albums = earliest_albums.reset_index(drop=True)
print(earliest_albums)

earliest_albums.to_csv('najwczeniej_wydane_albumy.csv', index=False)
# Out:
#     Pozycja                                   Tytuł                   Artysta  \
# 0        46                           greatest hits                      abba
# 1         4                                      21                     adele
# 2        41                      jagged little pill         alanis morissette
# 3        13                           back to black             amy winehouse
# 4         3    sgt pepper's lonely hearts club band                   beatles
# 5        16                                  legend  bob marley & the wailers
# 6        45                              parachutes                  coldplay
# 7        28                         talk on corners                     corrs
# 8        26                            white ladder                david gray
# 9        25                                no angel                      dido
# 10        8                        brothers in arms              dire straits
# ...
